# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
y405 = np.loadtxt("/Users/aled/Downloads/wavelengths/405.txt", skiprows=30, max_rows=2000)
y520 = np.loadtxt("/Users/aled/Downloads/wavelengths/520.txt", skiprows=30, max_rows=2000)
y650 = np.loadtxt("/Users/aled/Downloads/wavelengths/650.txt", skiprows=30, max_rows=2000)
y808 = np.loadtxt("/Users/aled/Downloads/wavelengths/808.txt", skiprows=30, max_rows=2000)
y909 = np.loadtxt("/Users/aled/Downloads/wavelengths/909.txt", skiprows=30, max_rows=2000)

# %%
my = lambda x: x[::,0][np.argmax(x[::,1])]
my(y405), my(y520[y520[::,0] < 600]), my(y650), my(y808), my(y909)
# Out:
# (np.float64(406.61),
#  np.float64(473.73),
#  np.float64(650.16),
#  np.float64(810.4),
#  np.float64(908.5))

# %%
y520
# Out:
# array([[ 344.74,  501.68],
#        [ 345.12,  546.88],
#        [ 345.5 ,  528.8 ],
#        ...,
#        [1018.03,  890.37],
#        [1018.32,  849.7 ],
#        [1018.6 ,  799.98]])
